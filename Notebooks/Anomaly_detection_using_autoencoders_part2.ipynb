# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishsaini01/Anomaly_detection_using_autoencoders/blob/main/Anomaly_detection_using_autoencoders_part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing libraries
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Conv2DTranspose
# from tensorflow.keras.preprocessing.image import ImageDataGenerator

from keras_preprocessing.image import ImageDataGenerator

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import random
import pickle

import pandas as pd
import seaborn as sns
import cv2

# %%
# mounting google drive for easy data reading
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# minimize the data and reshape it to 128*128*1
a_file = open('/content/drive/MyDrive/Colab Notebooks/data_of_502_images(128).pkl', 'rb')
file_pic = pickle.load(a_file)

img_array = np.array(list(file_pic.values()))
img_array = img_array.astype('float32') / 255.
img_array = np.reshape(img_array, (len(img_array), 128, 128, 1))

x_train = img_array[:2000]
x_test = img_array[2000:]

# %%
# Size of input image
Size = 128

# %%
# Encoder
model = Sequential()

model.add(Conv2D(24, (3, 3), activation='relu', padding='same', input_shape=(Size, Size, 1), strides = 2))

model.add(Conv2D(16, (3, 3), activation='relu', padding='same', strides = 2))

model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))


#Decoder
model.add(Conv2DTranspose(8, (3, 3), activation='relu', padding='same'))

model.add(Conv2DTranspose(16, (3, 3), activation='relu', padding='same', strides = 2))

model.add(Conv2DTranspose(24, (3, 3), activation='relu', padding='same', strides = 2))

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3, mode = 'min') # for early stopping

# training of model using mean squared error as a loss function
model.add(Conv2D(1, (3, 3), activation='sigmoid', padding='same'))

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mse'])     # compiling using MSE loss

model.summary()

#Fit the model. 
history = model.fit(
        x_train, x_train,
        batch_size = 32,
        epochs=30,
        shuffle=True, callbacks=[callback],
        validation_data=(x_test, x_test))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 64, 64, 24)        240
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 16)        3472
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 8)         1160
#
#  conv2d_transpose (Conv2DTra  (None, 32, 32, 8)        584
#  nspose)
#
#  conv2d_transpose_1 (Conv2DT  (None, 64, 64, 16)       1168
#  ranspose)
#
#  conv2d_transpose_2 (Conv2DT  (None, 128, 128, 24)     3480
#  ranspose)
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 1)       217
#
# =================================================================
# Total params: 10,321
# Trainable params: 10,321
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 63/63 [==============================] - 14s 39ms/step - loss: 0.0173 - mse: 0.0173 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 2/30
# 63/63 [==============================] - 1s 23ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 3/30
# 63/63 [==============================] - 2s 26ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 4/30
# 63/63 [==============================] - 1s 23ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 5/30
# 63/63 [==============================] - 1s 23ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 6/30
# 63/63 [==============================] - 2s 26ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 7/30
# 63/63 [==============================] - 1s 23ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 8/30
# 63/63 [==============================] - 1s 23ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 9/30
# 63/63 [==============================] - 1s 23ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 10/30
# 63/63 [==============================] - 1s 23ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 11/30
# 63/63 [==============================] - 1s 23ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 12/30
# 63/63 [==============================] - 1s 23ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 13/30
# 63/63 [==============================] - 1s 23ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 14/30
# 63/63 [==============================] - 1s 23ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 15/30
# 63/63 [==============================] - 1s 23ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 16/30
# 63/63 [==============================] - 1s 24ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 17/30
# 63/63 [==============================] - 1s 23ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 18/30
# 63/63 [==============================] - 1s 23ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 19/30
# 63/63 [==============================] - 1s 24ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 20/30
# 63/63 [==============================] - 1s 24ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 21/30
# 63/63 [==============================] - 1s 23ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 22/30
# 63/63 [==============================] - 1s 23ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 23/30
# 63/63 [==============================] - 1s 23ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 24/30
# 63/63 [==============================] - 1s 23ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 25/30
# 63/63 [==============================] - 1s 24ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 26/30
# 63/63 [==============================] - 2s 24ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 27/30
# 63/63 [==============================] - 1s 24ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 28/30
# 63/63 [==============================] - 2s 24ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 29/30
# 63/63 [==============================] - 1s 24ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 30/30
# 63/63 [==============================] - 2s 24ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0019 - val_mse: 0.0019

# %%
# train and val loss using mse
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['loss', 'val_loss'])
plt.show()

# %%
# # store the train model into pickle file
# a_file = open("/content/drive/MyDrive/Colab Notebooks/model_with_sigmoid_without_maxpooling_try_13.07.pkl", "wb")
# pickle.dump(model, a_file)
# a_file.close()

# %%
# caclulating reconstruction error for model trained using mse loss
reconstruction = model.predict(x_test)
test_loss = tf.keras.losses.mse(reconstruction, x_test)

# %%
# calculating loss for test images
loss_ls = []
for i in range(0, len(x_test)):
  score = model.evaluate(reconstruction[i], x_test[i])
  loss_ls.append(score[0])

loss_df = pd.DataFrame(loss_ls, columns = ['Loss']) 

smallest_loss = loss_df.nsmallest(5, columns = ['Loss'])
largest_loss = loss_df.nlargest(5, columns = ['Loss'])

min_index_ls = smallest_loss.index.tolist()
min_loss = smallest_loss.Loss.tolist()

max_index_ls = largest_loss.index.tolist()
max_loss = largest_loss.Loss.tolist()

# %%
print(model.evaluate(reconstruction, x_test))
print(model.evaluate(x_test, x_test))
# Out:
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0024 - mse: 0.0024
# [0.002428513951599598, 0.002428513951599598]
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0019 - mse: 0.0019
# [0.0019402309553697705, 0.0019402309553697705]

# %%
ax = sns.distplot(loss_ls)
ax.set_title('Histogram of loss between reconstruction and orignal image')
sns.despine()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
histogram_1, bin_edges_1 = np.histogram(x_test[min_index_ls[0]].reshape(128,128), bins=256, range=(0, 1))
histogram, bin_edges = np.histogram(reconstruction[min_index_ls[0]].reshape(128,128), bins=256, range=(0, 1))

fig = plt.figure(figsize=(10,5))
fig.suptitle('Histogram of image which has low loss')
axes = fig.subplots(1, 2)

axes[0].plot(bin_edges_1[0:-1], histogram_1, 'tab:orange')
axes[0].set_title('original image')
axes[1].plot(bin_edges[0:-1], histogram)
axes[1].set_title('reconstruction image')

plt.show()

# %%
histogram_1, bin_edges_1 = np.histogram(x_test[max_index_ls[0]].reshape(128,128), bins=256, range=(0, 1))
histogram, bin_edges = np.histogram(reconstruction[max_index_ls[0]].reshape(128,128), bins=256, range=(0, 1))

fig = plt.figure(figsize=(10,5))
fig.suptitle('Histogram of image which has high loss')
axes = fig.subplots(1, 2)

axes[0].plot(bin_edges_1[0:-1], histogram_1, 'tab:orange')
axes[0].set_title('original image')
axes[1].plot(bin_edges[0:-1], histogram)
axes[1].set_title('reconstruction image')

plt.show()

# %%
# 5 orignal images and their reconstruction where the loss is minimum
n = 5
plt.figure(figsize=(20, 5), dpi=100)
for i in range(0, n):
    # Display original
    ax = plt.subplot(2, n, i+1)
    plt.imshow(x_test[min_index_ls[i]].reshape(128, 128))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    plt.title("Original")
    ax.get_yaxis().set_visible(False)
    ax.set_title("Original Image")

    # Display reconstruction
    ax = plt.subplot(2, n, i + n + 1)
    plt.title("Reconstructed")
    plt.imshow(reconstruction[min_index_ls[i]].reshape(128, 128))
    # plt.gray()
    ax.get_xaxis().set_visible(True)
    ax.get_yaxis().set_visible(False)
    ax.set_title("Reconstructed Image")
    label = 'Loss: {:.3f}'
    ax.set_xlabel(label.format(min_loss[i]) )
    
plt.show()

# %%
# orignal images and their reconstruction where the loss is high
n = 5
plt.figure(figsize=(20, 5), dpi=100)
for i in range(0, n):
    # Display original
    ax = plt.subplot(2, n, i+1)
    plt.imshow(x_test[max_index_ls[i]].reshape(128, 128))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    plt.title("Original")
    ax.get_yaxis().set_visible(False)
    ax.set_title("Original Image")

    # Display reconstruction
    ax = plt.subplot(2, n, i + n +1)
    plt.title("Reconstructed")
    plt.imshow(reconstruction[max_index_ls[i]].reshape(128, 128))
    # plt.gray()
    ax.get_xaxis().set_visible(True)
    ax.get_yaxis().set_visible(False)
    ax.set_title("Reconstructed Image")
    label = 'Loss: {:.3f}'
    ax.set_xlabel(label.format(max_loss[i]) )
    
plt.show()
